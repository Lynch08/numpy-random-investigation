# %% [markdown]
# # The Iris dataset and pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\lynch08\Desktop\GMITWinter2021\Programming_For_Data_Analysis\numpy-investigation\numpy-random-investigation\IrisdataCSV.csv')

# %%
df
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.loc[2:6]
# Out:
#    sepal length  sepal width  petal length  petal width      species
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa

# %%
df.loc[:,'species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
df.loc[2:6,['species', 'sepal length']]
# Out:
#        species  sepal length
# 2  Iris-setosa           4.7
# 3  Iris-setosa           4.6
# 4  Iris-setosa           5.0
# 5  Iris-setosa           5.4
# 6  Iris-setosa           4.6

# %%
df.iloc[2]
# Out:
# sepal length            4.7
# sepal width             3.2
# petal length            1.3
# petal width             0.2
# species         Iris-setosa
# Name: 2, dtype: object

# %%
df.iloc[2:4, 1]
# Out:
# 2    3.2
# 3    3.1
# Name: sepal width, dtype: float64

# %%
df.at[3,'species']
# Out:
# 'Iris-setosa'

# %%
df.iloc[0:10:2]
# Out:
#    sepal length  sepal width  petal length  petal width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa

# %% [markdown]
# # Boolean selects

# %%
df.loc[:, 'species'] =='Iris-setosa'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: species, Length: 150, dtype: bool

# %%
df.loc[df.loc[:, 'species'] =='Iris-versicolor']
# Out:
#     sepal length  sepal width  petal length  petal width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
# 55           5.7          2.8           4.5          1.3  Iris-versicolor
# 56           6.3          3.3           4.7          1.6  Iris-versicolor
# 57           4.9          2.4           3.3          1.0  Iris-versicolor
# 58           6.6          2.9           4.6          1.3  Iris-versicolor
# 59           5.2          2.7           3.9          1.4  Iris-versicolor
# 60           5.0          2.0           3.5          1.0  Iris-versicolor
# 61           5.9          3.0           4.2          1.5  Iris-versicolor
# ...

# %%
x = df.loc[df.loc[:, 'species'] == 'Iris-versicolor']

# %%
x.loc[51]
# Out:
# sepal length                6.4
# sepal width                 3.2
# petal length                4.5
# petal width                 1.5
# species         Iris-versicolor
# Name: 51, dtype: object

# %%
x.iloc[1]
# Out:
# sepal length                6.4
# sepal width                 3.2
# petal length                4.5
# petal width                 1.5
# species         Iris-versicolor
# Name: 51, dtype: object

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.mean()
# Out:
# sepal length    5.843333
# sepal width     3.054000
# petal length    3.758667
# petal width     1.198667
# dtype: float64

# %% [markdown]
# # Plots

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue = 'species')
